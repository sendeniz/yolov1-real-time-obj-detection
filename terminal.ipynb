# %% [markdown]
# ### Connect to google drive

# %%
from google.colab import drive
# mount drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Train Model
# We can train the model by simply calling the train.py function, thus using the notebook as a conesole or terminal.

# %%
# %cd /content/drive/MyDrive/yolo/
# !ls
# Out:
# /content/drive/MyDrive/yolo
# cpts			metric_tester.py  train.txt
# custom_transform.py	old_txt_files	  train_yolov1.py
# darknet_metric.py	opencv_video.py   voc_label.py
# darknet.py		plots_figs.py	  yolov1_loss.py
# data			__pycache__	  yolov1net.py
# data.py			requirements.txt  yolov1net_resnet18.py
# generate_csv.py		results		  yolov1net_resnet50.py
# get_data.sh		terminal.ipynb	  yolov1net_vgg19bn.py
# get_inference_speed.py	test.txt	  yolov1_watches_youtube.py
# metric.py		train_darknet.py

# %%
# %cd /content/drive/MyDrive/yolo/
# !python train_yolov1.py
# Out:
# /content/drive/MyDrive/yolo
# Petrained resnet 18 network initalized as a backbone.
# Checkpoint from epoch:131 successfully loaded.
# Learning Rate: 1e-06
# Epoch:131  Train[Loss:4.345073223114014 mAP:0.691207230091095]  Test[Loss:8.44234848022461 mAP:0.4435059428215027]
# Learning Rate: 1e-06
# Epoch:132  Train[Loss:4.939018249511719 mAP:0.6899980902671814]  Test[Loss:7.331880569458008 mAP:0.4462752938270569]
# Learning Rate: 1e-06
# Epoch:133  Train[Loss:2.499950408935547 mAP:0.6846206784248352]  Test[Loss:1.0597202777862549 mAP:0.44343891739845276]
# Learning Rate: 1e-06
# Epoch:134  Train[Loss:3.3115134239196777 mAP:0.6839364171028137]  Test[Loss:2.2675085067749023 mAP:0.4429486393928528]
# Learning Rate: 1e-06
# Epoch:135  Train[Loss:2.8539843559265137 mAP:0.6783179640769958]  Test[Loss:3.7038989067077637 mAP:0.4425809383392334]
# Checkpoint at 135 stored

# %%
# %cd /content/drive/MyDrive/yolo/
# !python get_inference_speed.py
# Out:
# /content/drive/MyDrive/yolo
# Petrained yolov1 vgg 19 network with batch normalization initalized.

# %%
# %cd /content/drive/MyDrive/yolo/
# !python figs.py
# Out:
# /content/drive/MyDrive/yolo
# Petrained yolov1 resnet 50 network initalized.
