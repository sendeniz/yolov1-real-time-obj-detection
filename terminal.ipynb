# %% [markdown]
# ### Connect to google drive

# %%
from google.colab import drive
# mount drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Check folder
# Does everythong look fine ?

# %%
# %cd /content/drive/MyDrive/yolov1-real-time-obj-detection-main/
# !ls
# Out:
# /content/drive/MyDrive/yolov1-real-time-obj-detection-main
# application  README.md	       utils
# cpts	     requirements.txt  venv
# data	     results	       video
# figures      setup.py	       yolov1_real_time_obj_detection.egg-info
# loss	     terminal.ipynb
# models	     train

# %% [markdown]
# ### Ensure virtualenv is upgraded

# %%
# !pip install --upgrade virtualenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting virtualenv
#   Downloading virtualenv-20.16.5-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 31.3 MB/s
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (5.0.0)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 64.8 MB/s
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (3.8.1)
# Installing collected packages: platformdirs, distlib, virtualenv
# Successfully installed distlib-0.3.6 platformdirs-2.5.2 virtualenv-20.16.5

# %% [markdown]
# ### Create Virtual Env

# %%
# !virtualenv -p python3 venv
# Out:
# created virtual environment CPython3.7.14.final.0-64 in 17220ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/yolov1-real-time-obj-detection-main/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.2.2, setuptools==65.3.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %% [markdown]
# ### Activate virtual env

# %%
# !source venv/bin/activate

# %% [markdown]
# ### Install package for relative imports

# %%
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/yolov1-real-time-obj-detection-main
# Installing collected packages: yolov1-real-time-obj-detection
#   Running setup.py develop for yolov1-real-time-obj-detection
# Successfully installed yolov1-real-time-obj-detection-1.0

# %% [markdown]
# ### Get data
# Note that on Linux and MacOS get_data.sh works, however google collab is not able to catch up with reading and writing on cloud. Some commands are not executed, files are skipped. I recommend running this locally and then uploading the folder manually to your google drive using the google drive application.

# %% [markdown]
# ### Train model
# We can use the notebook just like a terminal and train by calling the training.py.

# %%
# %cd /content/drive/MyDrive/yolov1-real-time-obj-detection-main/
# !python  models/tiny_yolov1net_resnet18.py
# Out:
# /content/drive/MyDrive/yolov1-real-time-obj-detection-main

# %%
# %cd /content/drive/MyDrive/yolov1-real-time-obj-detection-main/
# !python train/train_yolov1.py
# Out:
# /content/drive/MyDrive/yolov1-real-time-obj-detection-main
# Petrained tiny resnet 18 yolo network initalized as a backbone.
# Learning Rate: 1e-05
# Epoch:1  Train[Loss:11.41949462890625 mAP:0.0]  Test[Loss:47.38488006591797 mAP:0.0]
# Learning Rate: 2.8000000000000003e-05
# Epoch:2  Train[Loss:10.652303695678711 mAP:2.6787218303070404e-05]  Test[Loss:36.48418045043945 mAP:1.964260809472762e-05]
# Learning Rate: 4.6e-05
# Epoch:3  Train[Loss:35.269798278808594 mAP:0.00014958744577597827]  Test[Loss:62.424400329589844 mAP:0.00010351060336688533]
# Learning Rate: 6.4e-05
# Epoch:4  Train[Loss:3.205573558807373 mAP:0.0012432330986484885]  Test[Loss:18.32376480102539 mAP:0.0003758148232009262]
# Learning Rate: 8.2e-05
# Epoch:5  Train[Loss:6.594111919403076 mAP:0.003126937197521329]  Test[Loss:26.820281982421875 mAP:0.000891077215783298]
# Checkpoint at 5 stored
# Learning Rate: 0.0001
# Epoch:6  Train[Loss:2.5337932109832764 mAP:0.0029906064737588167]  Test[Loss:13.504733085632324 mAP:0.0018525624182075262]
# Learning Rate: 0.0001
# Epoch:7  Train[Loss:4.679052352905273 mAP:0.008162555284798145]  Test[Loss:23.829967498779297 mAP:0.0023237275891005993]
# Learning Rate: 0.0001
# Epoch:8  Train[Loss:2.45693302154541 mAP:0.01385586243122816]  Test[Loss:18.353572845458984 mAP:0.0049533299170434475]
# Learning Rate: 0.0001
# Epoch:9  Train[Loss:10.837957382202148 mAP:0.011275028809905052]  Test[Loss:15.236100196838379 mAP:0.002384952735155821]
# Learning Rate: 0.0001
# Epoch:10  Train[Loss:7.54608154296875 mAP:0.018731409683823586]  Test[Loss:34.97438049316406 mAP:0.00876967329531908]
# Checkpoint at 10 stored
# Learning Rate: 0.0001
# Epoch:11  Train[Loss:13.281201362609863 mAP:0.024060484021902084]  Test[Loss:7.569127082824707 mAP:0.013523153960704803]
# Learning Rate: 0.0001
# Epoch:12  Train[Loss:4.862607002258301 mAP:0.0272547397762537]  Test[Loss:37.590511322021484 mAP:0.02030855603516102]
# Learning Rate: 0.0001
# Epoch:13  Train[Loss:3.976743221282959 mAP:0.025370169430971146]  Test[Loss:27.695083618164062 mAP:0.016388054937124252]
# Learning Rate: 0.0001
# Epoch:14  Train[Loss:6.46750020980835 mAP:0.030674412846565247]  Test[Loss:25.79130744934082 mAP:0.013109356164932251]
# Learning Rate: 0.0001
# Epoch:15  Train[Loss:22.8574161529541 mAP:0.038864199072122574]  Test[Loss:37.11799621582031 mAP:0.026870474219322205]
# Checkpoint at 15 stored
# Learning Rate: 0.0001
# Epoch:16  Train[Loss:6.251772403717041 mAP:0.038693077862262726]  Test[Loss:12.07978343963623 mAP:0.02407146990299225]
# Learning Rate: 0.0001
# Epoch:17  Train[Loss:1.7535443305969238 mAP:0.016535934060811996]  Test[Loss:42.986854553222656 mAP:0.00903878454118967]
# Learning Rate: 0.0001
# Epoch:18  Train[Loss:5.194520473480225 mAP:0.03945615515112877]  Test[Loss:20.824607849121094 mAP:0.023300088942050934]
# Learning Rate: 0.0001
# Epoch:19  Train[Loss:4.828286170959473 mAP:0.04363735020160675]  Test[Loss:11.899945259094238 mAP:0.02599361538887024]
# Learning Rate: 0.0001
# Epoch:20  Train[Loss:11.499580383300781 mAP:0.04476868733763695]  Test[Loss:23.135833740234375 mAP:0.021606456488370895]
# Checkpoint at 20 stored
# Learning Rate: 0.0001
# Epoch:21  Train[Loss:10.357719421386719 mAP:0.05421394109725952]  Test[Loss:17.530792236328125 mAP:0.0322103425860405]
# Learning Rate: 0.0001
# Epoch:22  Train[Loss:3.2300615310668945 mAP:0.04579484462738037]  Test[Loss:12.646464347839355 mAP:0.021326158195734024]
# Learning Rate: 0.0001
# Epoch:23  Train[Loss:1.6096796989440918 mAP:0.0522431805729866]  Test[Loss:10.32839298248291 mAP:0.026753539219498634]
# Learning Rate: 0.0001
# Epoch:24  Train[Loss:13.540079116821289 mAP:0.06791160255670547]  Test[Loss:23.467531204223633 mAP:0.05277111008763313]
# Learning Rate: 0.0001
# Epoch:25  Train[Loss:5.465363025665283 mAP:0.07015430182218552]  Test[Loss:16.024864196777344 mAP:0.044528778642416]
# Checkpoint at 25 stored
# Learning Rate: 0.0001
# Epoch:26  Train[Loss:6.265021324157715 mAP:0.057822443544864655]  Test[Loss:21.849321365356445 mAP:0.03801650553941727]
# Learning Rate: 0.0001
# Epoch:27  Train[Loss:7.323112487792969 mAP:0.07401926815509796]  Test[Loss:16.20001792907715 mAP:0.04893247410655022]
# Learning Rate: 0.0001
# Epoch:28  Train[Loss:3.754817008972168 mAP:0.0808965414762497]  Test[Loss:13.203779220581055 mAP:0.050940025597810745]
# Learning Rate: 0.0001
# Epoch:29  Train[Loss:2.9145631790161133 mAP:0.07131056487560272]  Test[Loss:45.249141693115234 mAP:0.053212910890579224]
# Learning Rate: 0.0001
# Epoch:30  Train[Loss:23.03081703186035 mAP:0.08381511270999908]  Test[Loss:18.288089752197266 mAP:0.052087921649217606]
# Checkpoint at 30 stored
# Learning Rate: 0.0001
# Epoch:31  Train[Loss:10.071722984313965 mAP:0.09530685842037201]  Test[Loss:16.753435134887695 mAP:0.06276129186153412]
# Learning Rate: 0.0001
# Epoch:32  Train[Loss:4.399300575256348 mAP:0.09640228003263474]  Test[Loss:25.432701110839844 mAP:0.07111626118421555]
# Learning Rate: 0.0001
# Epoch:33  Train[Loss:4.012039661407471 mAP:0.09664935618638992]  Test[Loss:13.468966484069824 mAP:0.06209763139486313]
# Learning Rate: 0.0001
# Epoch:34  Train[Loss:7.852874755859375 mAP:0.0888250395655632]  Test[Loss:20.527233123779297 mAP:0.05380100756883621]
# Learning Rate: 0.0001
# Epoch:35  Train[Loss:1.4354050159454346 mAP:0.10439443588256836]  Test[Loss:8.857452392578125 mAP:0.07464884221553802]
# Checkpoint at 35 stored
# Learning Rate: 0.0001
# Epoch:36  Train[Loss:5.367697238922119 mAP:0.10334175825119019]  Test[Loss:9.618635177612305 mAP:0.06574797630310059]
# Learning Rate: 0.0001
# Epoch:37  Train[Loss:2.388335704803467 mAP:0.11215437948703766]  Test[Loss:13.814571380615234 mAP:0.0818319022655487]
# Learning Rate: 0.0001
# Epoch:38  Train[Loss:3.4327211380004883 mAP:0.11772298812866211]  Test[Loss:6.687263488769531 mAP:0.07856433838605881]
# Learning Rate: 0.0001
# Epoch:39  Train[Loss:3.1285648345947266 mAP:0.11685385555028915]  Test[Loss:10.083807945251465 mAP:0.06693337857723236]
# Learning Rate: 0.0001
# Epoch:40  Train[Loss:17.754568099975586 mAP:0.12482069432735443]  Test[Loss:37.60821533203125 mAP:0.08988414704799652]
# Checkpoint at 40 stored
# Learning Rate: 0.0001
# Epoch:41  Train[Loss:4.3776044845581055 mAP:0.12994788587093353]  Test[Loss:12.336151123046875 mAP:0.08440165221691132]
# Learning Rate: 0.0001
# Epoch:42  Train[Loss:1.7162914276123047 mAP:0.1324763000011444]  Test[Loss:10.91633129119873 mAP:0.09170055389404297]
# Learning Rate: 0.0001
# Epoch:43  Train[Loss:2.3151779174804688 mAP:0.13412709534168243]  Test[Loss:22.1442928314209 mAP:0.09082110971212387]
# Learning Rate: 0.0001
# Epoch:44  Train[Loss:1.791373372077942 mAP:0.1371494084596634]  Test[Loss:6.471117973327637 mAP:0.11174926906824112]
# Learning Rate: 0.0001
# Epoch:45  Train[Loss:5.001983165740967 mAP:0.14365774393081665]  Test[Loss:5.939964294433594 mAP:0.1150166392326355]
# Checkpoint at 45 stored
# Learning Rate: 0.0001
# Epoch:46  Train[Loss:8.478776931762695 mAP:0.14713945984840393]  Test[Loss:22.142982482910156 mAP:0.09967745095491409]
# Learning Rate: 0.0001
# Epoch:47  Train[Loss:8.129691123962402 mAP:0.16196639835834503]  Test[Loss:10.902986526489258 mAP:0.1242021918296814]

# %% [markdown]
# ### Figures

# %%
# %cd /content/drive/MyDrive/yolov1-real-time-obj-detection-main/
# !python utils/get_inference_speed.py
# Out:
# /content/drive/MyDrive/yolov1-real-time-obj-detection-main
# Petrained tiny yolov1 resnet 18 network initalized.

# %%
# %cd /content/drive/MyDrive/yolov1-real-time-obj-detection-main/
# !python utils/figs.py
# Out:
# /content/drive/MyDrive/yolov1-real-time-obj-detection-main
# Petrained tiny yolov1 resnet 18 network initalized.

# %% [markdown]
# ### Real-time inference on video
# Make sure you have a .mp4 video file in in the video/ folder.

# %%
# %cd /content/drive/MyDrive/yolo/
# !python yolov1_watches_youtube.py
# Out:
# /content/drive/MyDrive/yolo
# Petrained yolov1 resnet 50 network initalized.
# Video processed in real time and saved.
